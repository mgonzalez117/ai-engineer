# %% [markdown]
# # Astrodynamics - Module d'atterrissage Eagle 1
# ## Installation & Exploration des espaces d'observation et d'actions

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from gymnasium.wrappers import RecordVideo
import mlflow
import os

env_name = 'LunarLander-v3'
video_folder = "./videos_dqn"
log_dir='./logs_dqn'
SEED=42

train_env = gym.make(env_name)
train_env.reset(seed=SEED)
train_env.action_space.seed(SEED)

video_env = gym.make(env_name, render_mode="rgb_array")
video_env.reset(seed=SEED)
video_env.action_space.seed(SEED)
video_env = RecordVideo(
    video_env,
    video_folder=video_folder,
    episode_trigger=lambda ep_id: True,  # enregistre tous les épisodes
    name_prefix="dqn_lunarlander"
)

# Afficher les espaces d'observation et d'action
print("Espace d'observation :", train_env.observation_space)
print("Espace d'action :", train_env.action_space)

# Obtenir dynamiquement les dimensions de ces espaces
states_dim = train_env.observation_space.shape[0]
actions_dim = train_env.action_space.n

print("Espace d'observation - dimensions :",states_dim)
print("Espace d'action - dimensions :", actions_dim)
# Out:
# Espace d'observation : Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)
# Espace d'action : Discrete(4)
# Espace d'observation - dimensions : 8
# Espace d'action - dimensions : 4
# /usr/local/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/site-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /app/src/mission/videos_dqn folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(

# %% [markdown]
# ### Espaces d'observation et d'actions
#
# Voir https://gymnasium.farama.org/environments/box2d/lunar_lander/

# %% [markdown]
# #### _Espace d'observation_:
#
# 1. Coordonnées de l'alunisseur
#    * x : position horizontale
#    * y : position verticale
# 3. Vitesses linéraies
#    * vx : vitesse horizontale
#    * vy : vitesse verticale
# 5. Angle et vitesse angulaire
#    * angle de l'alunisseur en radians
#    * vitesse de rotation
# 7. Etat de contact avec le sol
#    * Pied gauche touche le sol
#    * Pied droit touche le sol
#
# #### _Espace d'actions_:
#
# * 0 : pas d'action
# * 1 : moteur gauche allumé
# * 2 : moteur principal allumé
# * 3 : moteur droit allumé

# %% [markdown]
# ### Récompenses :
#
# Après chaque étape, une récompense est attribuée. La récompense totale d'un épisode correspond à la somme des récompenses attribuées pour toutes les étapes de cet épisode.
#
# Pour chaque étape, la récompense :
#
# * augmente/diminue à mesure que l'atterrisseur se rapproche/s'éloigne de la plate-forme d'atterrissage.
#
# * augmente/diminue à mesure que l'atterrisseur ralentit/accélère.
#
# * diminue à mesure que l'atterrisseur s'incline (angle non horizontal).
#
# * est augmentée de 10 points pour chaque jambe en contact avec le sol.
#
# * est diminuée de 0,03 point à chaque image où un moteur latéral est en marche.
#
# * est diminuée de 0,3 point à chaque image où le moteur principal est en marche.
#
# * L'épisode reçoit une récompense supplémentaire de -100 ou +100 points en cas de crash ou d'atterrissage en toute sécurité, respectivement.
#
# * Un épisode est considéré comme une solution s'il obtient au moins 200 points.

# %% [markdown]
# ## Experimentations itératives
#
# Pour mener ces expérimentations nous utilisons les outils :
# * MLFlow
# * Tensorboard

# %%
from stable_baselines3.common.callbacks import BaseCallback
from torch.utils.tensorboard import SummaryWriter
import os

# Définir le répertoire de logs TensorBoard
log_dir = "./tensorboard_logs/"
os.makedirs(log_dir, exist_ok=True)

mlflow.set_experiment("lunarlander-dqn")
model_name = "dqn_lunarlander"
NB_STEPS = 1000000

experiment = mlflow.get_experiment_by_name("lunarlander-dqn")
print(f"Experiment ID: {experiment.experiment_id}")
print(f"Tracking URI: {mlflow.get_tracking_uri()}")

hparams = dict(
    policy="MlpPolicy",
    learning_rate=0.003,
    buffer_size=50000,
    learning_starts=1000,
    target_update_interval=500,
    exploration_fraction=0.1,
    tensorboard_log=log_dir,
)

# Nom du run avec steps et learning_rate
run_name = f"{model_name}_{NB_STEPS}_steps_lr{hparams['learning_rate']}"

with mlflow.start_run(run_name=run_name) as run:
    # Récupérer l'ID du run MLflow
    run_id = run.info.run_id
    
    # Construire l'URL MLflow pour ce run
    tracking_uri = mlflow.get_tracking_uri()
    mlflow_url = f"{tracking_uri}/#/experiments/{experiment.experiment_id}/runs/{run_id}"
    
    print(f"MLflow Run ID: {run_id}")
    print(f"MLflow URL: {mlflow_url}")
    
    mlflow.log_param("nb_steps", NB_STEPS)
    mlflow.log_params(hparams)
    
    # Nom du log TensorBoard LISIBLE (pas le hash)
    tb_log_name = run_name
    
    model = DQN(
        policy=hparams["policy"],
        env=train_env,
        verbose=1,
        seed=SEED,
        learning_rate=hparams["learning_rate"],
        buffer_size=hparams["buffer_size"],
        learning_starts=hparams["learning_starts"],
        target_update_interval=hparams["target_update_interval"],
        exploration_fraction=hparams["exploration_fraction"],
        tensorboard_log=hparams["tensorboard_log"],
    )
    
    model.learn(
        total_timesteps=NB_STEPS,
        tb_log_name=tb_log_name
    )
    
    # Log les fichiers TensorBoard spécifiques à ce run dans MLflow
    specific_run_log_dir = os.path.join(log_dir, f"{tb_log_name}_1")
    if os.path.exists(specific_run_log_dir):
        # Ajouter le run_id comme tag dans TensorBoard
        writer = SummaryWriter(log_dir=specific_run_log_dir)
        writer.add_text("mlflow/run_id", run_id, 0)
        writer.add_text("mlflow/run_url", mlflow_url, 0)
        writer.add_text("mlflow/run_name", run_name, 0)
        writer.close()
        
        mlflow.log_artifacts(specific_run_log_dir, artifact_path="tensorboard_logs")
        
        # Créer un fichier texte avec le lien MLflow dans le dossier TensorBoard
        mlflow_link_file = os.path.join(specific_run_log_dir, "mlflow_link.txt")
        with open(mlflow_link_file, "w") as f:
            f.write(f"MLflow Run URL:\n{mlflow_url}\n\n")
            f.write(f"Run ID: {run_id}\n")
            f.write(f"Run Name: {run_name}\n")
        
        # Log aussi ce fichier dans MLflow
        mlflow.log_artifact(mlflow_link_file, artifact_path="tensorboard_logs")
    
    # Évaluation du modèle
    mean_reward, std_reward = evaluate_policy(
        model, 
        video_env, 
        n_eval_episodes=100,
        warn=False
    )
    
    video_env.close()
    print(f"Récompense moyenne sur 100 épisodes : {mean_reward:.2f} +/- {std_reward:.2f}")
    mlflow.log_metric("eval_mean_reward", float(mean_reward))
    mlflow.log_metric("eval_std_reward", float(std_reward))

     # Sauvegarder le modèle
    if mean_reward > 200:
        print(f" Score {mean_reward:.2f} > 200 : sauvegarde du modèle sur MLflow")
        
       
        model.save(model_name)
        model_path = f"{model_name}.zip"
    
        # Vérifier l'existence et logger
        if os.path.exists(model_path):
            mlflow.log_artifact(model_path, artifact_path="model")
            print(f"Modèle sauvegardé dans MLflow : {model_path}")
        else:
            print(f"ERREUR : Fichier {model_path} introuvable")
            print(f"  Fichiers présents : {os.listdir('.')}")
    
    #mlflow.end_run()
# Out:
# 2026/02/04 08:55:33 WARNING mlflow.utils.git_utils: Failed to import Git (the Git executable is probably not on your PATH), so Git SHA is not available. Error: Failed to initialize: Bad git executable.
# The git executable must be specified in one of the following ways:
#     - be included in your $PATH
#     - be set via $GIT_PYTHON_GIT_EXECUTABLE
#     - explicitly set via git.refresh(<full-path-to-git-executable>)
#
# All git commands will error until this is rectified.
#
# This initial message can be silenced or aggravated in the future by setting the
# $GIT_PYTHON_REFRESH environment variable. Use one of the following values:
#     - quiet|q|silence|s|silent|none|n|0: for no message or exception
#     - warn|w|warning|log|l|1: for a warning message (logging level CRITICAL, displayed by default)
#     - error|e|exception|raise|r|2: for a raised exception
#
# Example:
#     export GIT_PYTHON_REFRESH=quiet
# Experiment ID: 619582485636765788
# Tracking URI: http://p11-mlflow:5000
# MLflow Run ID: 570d853b8afa4fe9a39bf75e75d5f088
# MLflow URL: http://p11-mlflow:5000/#/experiments/619582485636765788/runs/570d853b8afa4fe9a39bf75e75d5f088
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./tensorboard_logs/dqn_lunarlander_1000000_steps_lr0.003_6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 10266    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -209     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 10487    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 746      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -221     |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7506     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1128     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 5.74     |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | -214     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4651     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1534     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.827    |
# |    n_updates        | 133      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 3864     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2008     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.06     |
# |    n_updates        | 251      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -201     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3527     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2406     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.344    |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.6     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3305     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2704     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.563    |
# |    n_updates        | 425      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 3166     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3034     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.92     |
# |    n_updates        | 508      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 3044     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3442     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.05     |
# |    n_updates        | 610      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2929     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3794     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.421    |
# |    n_updates        | 698      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2845     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4204     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.8      |
# |    n_updates        | 800      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2762     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4574     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.564    |
# |    n_updates        | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2711     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4896     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.241    |
# |    n_updates        | 973      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.3     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2682     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5227     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.382    |
# |    n_updates        | 1056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2636     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 5627     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.391    |
# |    n_updates        | 1156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2612     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6085     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.65     |
# |    n_updates        | 1271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2600     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6524     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.942    |
# |    n_updates        | 1380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2572     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 6887     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.378    |
# |    n_updates        | 1471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2543     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 7234     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.59     |
# |    n_updates        | 1558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2528     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7637     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.33     |
# |    n_updates        | 1659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2513     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 7985     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.14     |
# |    n_updates        | 1746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 2483     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8447     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.88     |
# |    n_updates        | 1861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 2475     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 8807     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.2      |
# |    n_updates        | 1951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.9     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 2456     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9109     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.424    |
# |    n_updates        | 2027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 2455     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 9410     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.51     |
# |    n_updates        | 2102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2428     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9792     |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.54     |
# |    n_updates        | 2197     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -152     |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2402     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10155    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.1      |
# |    n_updates        | 2288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.1     |
# |    ep_rew_mean      | -146     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2402     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10540    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.803    |
# |    n_updates        | 2384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2401     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 10929    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.396    |
# |    n_updates        | 2482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -143     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2401     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11238    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.83     |
# |    n_updates        | 2559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -141     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2389     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 11669    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.62     |
# |    n_updates        | 2667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.7     |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2369     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12078    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.53     |
# |    n_updates        | 2769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -139     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2355     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12547    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.26     |
# |    n_updates        | 2886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.1     |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2357     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 12952    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.49     |
# |    n_updates        | 2987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -137     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2349     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 13342    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.1      |
# |    n_updates        | 3085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.5     |
# |    ep_rew_mean      | -136     |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2332     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 13759    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.72     |
# |    n_updates        | 3189     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.8     |
# |    ep_rew_mean      | -134     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2329     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14159    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.386    |
# |    n_updates        | 3289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | -133     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2326     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14524    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.09     |
# |    n_updates        | 3380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2326     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14878    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.47     |
# |    n_updates        | 3469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -130     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2315     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15266    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 8.35     |
# |    n_updates        | 3566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2315     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 15681    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 5.61     |
# |    n_updates        | 3670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -129     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2310     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 16042    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.5      |
# |    n_updates        | 3760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.7     |
# |    ep_rew_mean      | -125     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2296     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16459    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.743    |
# |    n_updates        | 3864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2289     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16889    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.423    |
# |    n_updates        | 3972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2283     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17279    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.15     |
# |    n_updates        | 4069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2275     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 17684    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.46     |
# |    n_updates        | 4170     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -120     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2269     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 18091    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 11       |
# |    n_updates        | 4272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2268     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 18520    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.53     |
# |    n_updates        | 4379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -108     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2268     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 18925    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 5.3      |
# |    n_updates        | 4481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2268     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19227    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.96     |
# |    n_updates        | 4556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2261     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19603    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.419    |
# |    n_updates        | 4650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -111     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2255     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 19937    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.912    |
# |    n_updates        | 4734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | -112     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2252     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 20328    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.5      |
# |    n_updates        | 4831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | -110     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2250     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 20691    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.76     |
# |    n_updates        | 4922     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -109     |
# |    exploration_rate | 0.799    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2246     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 21108    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.639    |
# |    n_updates        | 5026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -106     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 2246     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 21450    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.08     |
# |    n_updates        | 5112     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.793    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 2246     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 21829    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.626    |
# |    n_updates        | 5207     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | -102     |
# |    exploration_rate | 0.789    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 2245     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 22248    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.484    |
# |    n_updates        | 5311     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | -100     |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 2236     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 22633    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 8.56     |
# |    n_updates        | 5408     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | -99.2    |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 2232     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 23056    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.2      |
# |    n_updates        | 5513     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | -97      |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 2232     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 23439    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.541    |
# |    n_updates        | 5609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | -96.4    |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 2227     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 23837    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.584    |
# |    n_updates        | 5709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.9     |
# |    ep_rew_mean      | -95.4    |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 2223     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 24318    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.932    |
# |    n_updates        | 5829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | -95.3    |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2215     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 24716    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.14     |
# |    n_updates        | 5928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -94.6    |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2213     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 25096    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.6      |
# |    n_updates        | 6023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | -89.6    |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2211     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 25488    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.627    |
# |    n_updates        | 6121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98       |
# |    ep_rew_mean      | -87.9    |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2209     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 25843    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.66     |
# |    n_updates        | 6210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -88.5    |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2204     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 26278    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.43     |
# |    n_updates        | 6319     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.7     |
# |    ep_rew_mean      | -88      |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2199     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 26662    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.464    |
# |    n_updates        | 6415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.5     |
# |    ep_rew_mean      | -84.6    |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2198     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 27024    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.47     |
# |    n_updates        | 6505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | -83.2    |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2197     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 27381    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.84     |
# |    n_updates        | 6595     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | -83.1    |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2194     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 27699    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.613    |
# |    n_updates        | 6674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.9     |
# |    ep_rew_mean      | -82.9    |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2192     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 28112    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.512    |
# |    n_updates        | 6777     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96       |
# |    ep_rew_mean      | -82.1    |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2188     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 28523    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.67     |
# |    n_updates        | 6880     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | -80.6    |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2185     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 28939    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.64     |
# |    n_updates        | 6984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.4     |
# |    ep_rew_mean      | -78.8    |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2179     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 29340    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.79     |
# |    n_updates        | 7084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.2     |
# |    ep_rew_mean      | -77.9    |
# |    exploration_rate | 0.717    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2176     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 29758    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 2.05     |
# |    n_updates        | 7189     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -79      |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2176     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 30198    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.04     |
# |    n_updates        | 7299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.7     |
# |    ep_rew_mean      | -81.2    |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2179     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 30656    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.75     |
# |    n_updates        | 7413     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.5     |
# |    ep_rew_mean      | -81.6    |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2175     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 31060    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 3.06     |
# |    n_updates        | 7514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -81.4    |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2169     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 31453    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.2      |
# |    n_updates        | 7613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2168     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 31880    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.764    |
# |    n_updates        | 7719     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -82      |
# |    exploration_rate | 0.694    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2168     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 32238    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.18     |
# |    n_updates        | 7809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -83.3    |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2163     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 32630    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.06     |
# |    n_updates        | 7907     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -82.3    |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2159     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 33048    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.887    |
# |    n_updates        | 8011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -82.2    |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2157     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 33464    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 8.18     |
# |    n_updates        | 8115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -80.5    |
# |    exploration_rate | 0.678    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2152     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 33848    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.8      |
# |    n_updates        | 8211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | -80      |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2149     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 34295    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.835    |
# |    n_updates        | 8323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -79.7    |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2147     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 34679    |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 18.1     |
# |    n_updates        | 8419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -79.7    |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 360      |
# ...
# |    time_elapsed     | 61       |
# |    total_timesteps  | 116339   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.313    |
# |    n_updates        | 28834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 672      |
# |    ep_rew_mean      | -67      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 1871     |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 119732   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.181    |
# |    n_updates        | 29682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 698      |
# |    ep_rew_mean      | -66.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 1862     |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 123732   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.167    |
# |    n_updates        | 30682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 729      |
# |    ep_rew_mean      | -69.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 1857     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 127609   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.223    |
# |    n_updates        | 31652    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 744      |
# |    ep_rew_mean      | -66.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 1851     |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 130165   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.226    |
# |    n_updates        | 32291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | -64.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 1844     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 133913   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.465    |
# |    n_updates        | 33228    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 777      |
# |    ep_rew_mean      | -55.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 1842     |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 136422   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.226    |
# |    n_updates        | 33855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 798      |
# |    ep_rew_mean      | -50.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 1837     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 139700   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.179    |
# |    n_updates        | 34674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 801      |
# |    ep_rew_mean      | -36.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 1834     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 142303   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.209    |
# |    n_updates        | 35325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | -28      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 1831     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 144975   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.163    |
# |    n_updates        | 35993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 817      |
# |    ep_rew_mean      | -17.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 1827     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 147837   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.178    |
# |    n_updates        | 36709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 817      |
# |    ep_rew_mean      | -8.95    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 1826     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 150237   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.154    |
# |    n_updates        | 37309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 822      |
# |    ep_rew_mean      | -1.52    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 1824     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 151806   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.151    |
# |    n_updates        | 37701    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 826      |
# |    ep_rew_mean      | 7.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 1820     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 155061   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.239    |
# |    n_updates        | 38515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 823      |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 1817     |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 157026   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.146    |
# |    n_updates        | 39006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 828      |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 1814     |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 160040   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.295    |
# |    n_updates        | 39759    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 827      |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 1810     |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 163940   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 1.4      |
# |    n_updates        | 40734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 833      |
# |    ep_rew_mean      | 30.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 1806     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 167710   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.269    |
# |    n_updates        | 41677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 820      |
# |    ep_rew_mean      | 38.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 1804     |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 170383   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.119    |
# |    n_updates        | 42345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 812      |
# |    ep_rew_mean      | 48.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 1800     |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 173530   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.614    |
# |    n_updates        | 43132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 786      |
# |    ep_rew_mean      | 54.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 1799     |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 174917   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.21     |
# |    n_updates        | 43479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 761      |
# |    ep_rew_mean      | 58.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 1797     |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 176392   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.137    |
# |    n_updates        | 43847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 734      |
# |    ep_rew_mean      | 55.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 1795     |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 177710   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.186    |
# |    n_updates        | 44177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 58       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 1792     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 180594   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.148    |
# |    n_updates        | 44898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 723      |
# |    ep_rew_mean      | 59.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 1789     |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 184594   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.674    |
# |    n_updates        | 45898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 695      |
# |    ep_rew_mean      | 61.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 1789     |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 185834   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.14     |
# |    n_updates        | 46208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 683      |
# |    ep_rew_mean      | 69.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 1788     |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 188000   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.0686   |
# |    n_updates        | 46749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 673      |
# |    ep_rew_mean      | 72.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 1787     |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 191039   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.149    |
# |    n_updates        | 47509    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 655      |
# |    ep_rew_mean      | 86.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 1784     |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 193141   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.113    |
# |    n_updates        | 48035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 647      |
# |    ep_rew_mean      | 89.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 1782     |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 194880   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.735    |
# |    n_updates        | 48469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 629      |
# |    ep_rew_mean      | 98.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 1781     |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 196834   |
# | train/              |          |
# |    learning_rate    | 0.003    |
# |    loss             | 0.216    |
# |    n_updates        | 48958    |
# ----------------------------------
