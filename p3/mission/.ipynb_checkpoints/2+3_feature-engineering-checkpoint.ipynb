# %%
### On exécute le précédent notebook car on est dépendant des résultats
import sys
import os
from contextlib import redirect_stdout, redirect_stderr

# Désactiver l'affichage AVANT d'importer matplotlib
# %matplotlib agg

with open(os.devnull, 'w') as fnull:
    with redirect_stdout(fnull), redirect_stderr(fnull):
        # %run 1_analyse-exploratoire.ipynb

# FORCER la réactivation de l'affichage
# %matplotlib inline

# Réinitialiser matplotlib pour forcer le nouveau backend
import matplotlib
matplotlib.pyplot.close('all')  # Fermer toutes les figures existantes
# Out:
#      OSEBuildingID  DataYear    BuildingType          PrimaryPropertyType  \
# 513            700      2016  NonResidential  Supermarket / Grocery Store
#
#                   PropertyName  ZipCode TaxParcelIdentificationNumber  \
# 513  IUC- Whole Foods Interbay  98119.0                    7666201460
#
#      CouncilDistrictCode           Neighborhood  Latitude  ...  \
# 513                    7  MAGNOLIA / QUEEN ANNE  47.63718  ...
#
#      SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  Electricity(kWh)  \
# 513             12843856.0             0.0               0.0
#
#      Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  DefaultData  \
# 513                0.0                 0.0               0.0        False
#
#     ComplianceStatus TotalGHGEmissions  GHGEmissionsIntensity
# 513        Compliant               0.0                    0.0
#
# [1 rows x 41 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np

scaler = MinMaxScaler()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Matrice de corrélation des principales variables d'origine
#
# Nous faisons une première matrice de correlation de Pearson entre les variables que nous avons gardées afin de préparer le feature engineering.
# Nous cherchons à voir :
#
# * quelles variables sont corrélées à nos variables cibles, elles seront probablement de bonnes variables prédictives
# * quelles variables sont corrélées entre elles, il faudrait éviter de les utiliser entre elles pour réduire la multicolinéarité
#
# On se limite aux variables numériques car la matrice de Pearson ne fonctionne qu'avec des variables numériques. Toutefois on pourra transformer ultérieurement des non numériques en numériques selon leur pertinence pour la prédiction.
#
# **Remarque: il convient de ne pas surinterpréter les résultats, car la corrélation de Pearson (et donc la matrice de corrélation associée) ne capte que les relations linéaires et est sensible aux valeurs aberrantes.**

# %%
def display_pearson_matrix(matrix, title, annot=True):
    plt.figure(figsize=(12, 10))
    sns.heatmap(matrix, annot=annot, fmt=".2f", cmap='coolwarm', center=0)
    plt.title(title)
    plt.tight_layout()
    plt.show()
    
df_numeric = df.select_dtypes(include='number')

# Retirer les colonnes "synonymes" aux variables cibles (ce ne sont pas exactement les mêmes données mais nous nous concentrons sur ce que représentent les variables cibles)
columns_to_remove = [
    'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SiteEUI(kBtu/sf)', 'SiteEUIWN(kBtu/sf)',
    'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'NaturalGas(therms)', 'NaturalGas(kBtu)', 'Electricity(kWh)',
    'Electricity(kBtu)', 'SteamUse(kBtu)', 'GHGEmissionsIntensity'
]

# Supprimer les colonnes synonymes si elles existent
df_numeric = df_numeric.drop(columns=[col for col in columns_to_remove if col in df_numeric.columns])

initial_matrix = df_numeric.corr(method='pearson')

display_pearson_matrix(initial_matrix, "Matrice de corrélation de Pearson sur le jeu de données d'origine (réduit)", False)

# %% [markdown]
# ### Bilan
#
# On constate des corrélations fortes entre :
# * `PropertyGFATotal` et `PropertyGFABuilding(s)`, `LargestPropertyUseTypeGFA`
#
# On constate des corrélations relativement hautes entre plusieurs variables entre elles **qu'il faudrait réduire** :
# * `NumberofFloors` => `PropertyGFATotal`, `PropertyGFABuilding(s)`, etc.
#
# ## Besoins en données
# On a besoin à minima des données suivantes :
#
# * Surface totale
# * Localisation
# * Usage du bâtiment
# * Nombre de bâtiments et / ou d'étages (surface exposée à l'air)
# * Année de construction
# * Type de source d'énergie

# %% [markdown]
# ## Features
#
# ### Surface totale
#
# On a vu précédemment que la surface totale `PropertyGFATotal` possède une forte corrélation avec `NumberofFloors` que l'on gardera aussi en tant que feature. Il faut donc **réduire cette corrélation pour éviter d'induire le modèle en erreur**.
#
#   * on crée une nouvelle feature `FootprintGFA`, qui représente l'empreinte au sol :

# %%
# Calcul de la feature FootprintGFA
floors = df["NumberofFloors"].clip(lower=1)  # évite division par 0, traite 0 comme 1. 

df["FootprintGFA"] = df["PropertyGFABuilding(s)"] / floors

# Distribution FootprintGFA
plt.figure(figsize=(10, 6))
plt.hist(df['PropertyGFATotal'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribution de FootprintGFA')
plt.xlabel('FootprintGFA')
plt.ylabel('Fréquence')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
#  * on utilise MinMaxScaler pour diminuer la grande amplitude des données

# %%
df['PropertyGFATotalScaled'] = scaler.fit_transform(df[['PropertyGFATotal']])
df['PropertyGFABuilding(s)Scaled'] = scaler.fit_transform(df[['PropertyGFABuilding(s)']])
df['FootprintGFA'] = scaler.fit_transform(df[['FootprintGFA']])
plt.figure(figsize=(10, 6))
plt.hist(df['FootprintGFA'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribution de FootprintGFA (scaled)')
plt.xlabel('FootprintGFA')
plt.ylabel('Fréquence')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Localisation
#   * `Neighborhood` : information pertinente en terme de localisation, car elle peut englober un facteur d'architecture d'urbanisme qui fera potentiellement varier les résultats (exemple : dépendance de tout un quartier à une infrastructure électrique comme un ou plusieurs transformateurs). On utilise un **OneHotEncoder** car il s'agit d'une catégorie non ordinale

# %%
# Appliquer le One-Hot Encoding sur Neighborhood, d'après l'analyse précédente on va limiter à 12 le nombre de catégories
encoder = OneHotEncoder(sparse_output=False, max_categories=12, drop="first")
neighborhood_prefix = 'Neighborhood'
neighborhood_encoded = encoder.fit_transform(df[[neighborhood_prefix]])

# Ajouter les colonnes encodées directement au DataFrame
df = pd.concat([df.drop(neighborhood_prefix, axis=1),
                pd.DataFrame(neighborhood_encoded,
                           columns=encoder.get_feature_names_out([neighborhood_prefix]),
                           index=df.index)], axis=1)

# Vérification
neighborhood_columns = [col for col in df.columns if col.startswith(neighborhood_prefix+'_')]
print(f"Nombre de nouvelles colonnes Neighborhood_ créées : {len(neighborhood_columns)}")
# Out:
# Nombre de nouvelles colonnes Neighborhood_ créées : 11

# %% [markdown]
#   * `Lat` / `Lng` : ces données de localisation sont très fines mais le modèle ne comprendra naturellement pas l'aspect géographique. On va grouper les données (clusters) afin de capter des effets locaux / zones caractéristiques.

# %%
# Appliquer le K-means sur Lat & Lng
n_clusters = 8 # à ajuster selon la taille de la ville
coords = df[['Latitude', 'Longitude']]
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['GeoCluster'] = kmeans.fit_predict(coords)

# Affichage de la courbe GeoCluster 
# Visualiser la répartition géographique des clusters
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Longitude', y='Latitude', hue='GeoCluster', palette='tab10')
plt.title('Répartition géographique des clusters')
plt.show()

# Visualiser la distribution des variables cible par cluster
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='GeoCluster', y='TotalGHGEmissions')
plt.title('Distribution de TotalGHGEmissions par GeoCluster')
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='GeoCluster', y='SiteEnergyUse(kBtu)')
plt.title('Distribution de SiteEnergyUse(kBtu) par GeoCluster')
plt.show()

# %% [markdown]
# **Remarque : On constate qu'il n'y a pas de relation ordinale avec les clusters ce qui est tout à fait cohérent. On va utiliser un OneHotEncoder pour séparer les GeoClusters.**

# %%
geo_cluster_prefix = 'GeoCluster'
encoder = OneHotEncoder(drop='first', sparse_output=False)
geo_encoded = encoder.fit_transform(df[[geo_cluster_prefix]])
feature_names = encoder.get_feature_names_out([geo_cluster_prefix])
df = pd.concat([df.drop(columns=[geo_cluster_prefix]),
                pd.DataFrame(geo_encoded, columns=feature_names, index=df.index)], axis=1)

# %% [markdown]
# ### Usages du bâtiment
#
# * `PrimaryPropertyType` est l'usage principal du bâtiment, cette variable est critique pour mesurer la consommation. On ne peut pas l'utiliser telle quelle, on va appliquer un OneHot Encoding.

# %%
# Appliquer le one-hot encoding sur PrimaryPropertyType
col_name = [c for c in df.columns if c.lower().replace(' ','').replace('_','') == 'primarypropertytype'][0]
primary_type_prefix = 'Type'
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded = encoder.fit_transform(df[[col_name]])
feature_names = encoder.get_feature_names_out([col_name])
df = pd.concat([df.drop(columns=[col_name]),
                pd.DataFrame(encoded, columns=[n.replace(f"{col_name}_", primary_type_prefix+"_") for n in feature_names], index=df.index)], axis=1)

# Vérifier le résultat
print(f"Nombre de colonnes d'usage primaire créées : {len([col for col in df.columns if col.startswith(primary_type_prefix+'_')])}")
# Out:
# Nombre de colonnes d'usage primaire créées : 18

# %% [markdown]
# * On crée une feature pour savoir si un bâtiment a **plusieurs** usages.

# %%
df['MultipleUsages'] = df['ListOfAllPropertyUseTypes'].str.contains(',', na=False).astype(int)

# %% [markdown]
# #### Usages spécifiques très consommateurs en énergie
#
# Dans les différentes colonnes d'usages des bâtiments on peut constater certains qui sont très consommateurs en énergie :
#
# * `Data Center`
# * `Refrigerated Warehouse`
# * `Manufacturing/Industrial Plant`
# * `Swimming Pool`
# * `Supermarket/Grocery Store`
# * `Movie Theater`
# * `Museum`

# %%
# Liste des usages énergivores
high_energy_uses = [
    'Data Center', 'Refrigerated Warehouse', 'Manufacturing/Industrial Plant', 'Supermarket/Grocery Store', 'Movie Theater', 'Museum'
]

# Initialiser les nouvelles colonnes à 0
for use in high_energy_uses:
    col_name = f"{use.replace('/', '').replace(' ', '')}GFA"
    df[col_name] = 0


# Parcourir chaque ligne pour remplir les nouvelles colonnes
for index, row in df.iterrows():
    # Vérifier les trois colonnes d'usage
    for i in range(1, 4):
        use_type_col = f"{['Largest', 'SecondLargest', 'ThirdLargest'][i-1]}PropertyUseType"
        gfa_col = f"{['Largest', 'SecondLargest', 'ThirdLargest'][i-1]}PropertyUseTypeGFA"
        
        use_type = row[use_type_col]
        gfa = row[gfa_col]
        
        # Si l'usage est un usage énergivore, remplir la colonne correspondante
        if pd.notna(use_type):
            df.at[index, 'HasSwimmingPool'] = 0
            if use_type == 'Swimming Pool':
                df.at[index, 'HasSwimmingPool'] = 1
            elif use_type in high_energy_uses:
                new_col_name = f"{use_type.replace('/', '').replace(' ', '')}GFA"
                df.at[index, new_col_name] = gfa


# Sélectionner uniquement les nouvelles colonnes créées
new_columns = [col for col in df.columns if 'GFA' in col and any(use.replace('/', '').replace(' ', '') in col for use in high_energy_uses)]

# Filtrer les lignes où au moins une des nouvelles colonnes est différente de zéro
filtered_df = df[df[new_columns].any(axis=1)]

# Afficher un aperçu des nouvelles colonnes avec des valeurs non nulles
filtered_df[new_columns].head(10)
# Out:
#       OSEBuildingID  DataYear        BuildingType  \
# 4                 8      2016      NonResidential
# 16               22      2016      NonResidential
# 144             232      2016      NonResidential
# 501             682      2016      NonResidential
# 1606          22801      2016  Nonresidential COS
# 3155          45287      2016  Nonresidential COS
# 3221          49802      2016      NonResidential
# 3337          50062      2016      NonResidential
# 3373          50224      2016  Nonresidential COS
#
#                            PropertyName  ZipCode  \
# 4           WARWICK SEATTLE HOTEL (ID8)  98121.0
# 16                Downtown Seattle YMCA  98104.0
# 144                    Silver Cloud Inn  98109.0
# 501                West Seattle Fitness  98121.0
# 1606  Meadowbrook Community Center/Pool  98125.0
# 3155                  Medgar Evers Pool  98122.0
# 3221                      Hotel Ballard  98107.0
# 3337                Olympic Hospitality  98103.0
# ...

# %% [markdown]
# ### Nombre de bâtiments et / ou d'étages (surface exposée à l'air)
#
# * Nombre de bâtiments `NumberofBuildings` : on constate qu'il y a quelques données outlier, notamment le `University of Washington - Seattle Campus` qui a une donnée extrême de **111** bâtiments. On fait le choix de garder cette donnée car elle est vérifiée, toutefois on pourra agir dessus si besoin selon les performances du modèle

# %%
# décommenter pour décrire et voir les outliers
# print(df[['NumberofFloors', 'NumberofBuildings']].describe())
# display((df['NumberofBuildings'] > 12).sum())

# %% [markdown]
# * Nombre d'étages `NumberofFloors` : on constate un outlier qui est une erreur : `Seattle Chinese Baptist Church` est notée comme ayant 99 étages, en réalité l'église semble n'avoir que 2 étages (vérifié sur le net). On corrige donc cette valeur abbérante.

# %%
# décommenter pour voir les bâtiments qui ont plus de 40 étages
# display(df[df['NumberofFloors'] > 40])

# correction du nombre d'étages pour l'église Chinese Baptiste
df.loc[df['OSEBuildingID'] == 21611, 'NumberofFloors'] = 2

# %% [markdown]
# ### Année de construction
#
# L'année de construction nous permet de déduire des consommations en énergie / C02 à partir de l'âge d'un bâtiment.
# On va se servir de cette donnée pour créer une nouvelle feature `BuildingAge` **calculée à partir de la date de collecte des données**
#
# **Attention : Bien que l'âge peut être très pertinent pour la prédiction, il va également entrainer du drift du modèle. Il faudra donc régulièrement réentrainer notre modèle si l'on utilise cette feature**

# %%
print("=== ANALYSE DE LA VARIABLE YearBuilt ===")
print(f"Nombre total de bâtiments: {len(df)}")
print(f"Valeurs manquantes: {df['YearBuilt'].isna().sum()}")
print(f"Année minimum: {df['YearBuilt'].min()}")
print(f"Année maximum: {df['YearBuilt'].max()}")
print(f"Médiane: {df['YearBuilt'].median()}")

# Compter le nombre de bâtiments par année
year_counts = df['YearBuilt'].value_counts().sort_index()

# Créer l'histogramme
plt.figure(figsize=(15, 8))
bars = plt.bar(year_counts.index, year_counts.values, color='lightcoral', alpha=0.7, edgecolor='black', width=0.8)
plt.title('Répartition des bâtiments par année de construction', fontsize=16, fontweight='bold')
plt.ylabel('Nombre de bâtiments', fontsize=12)
plt.xlabel('Année de construction', fontsize=12)
plt.grid(axis='y', alpha=0.3)

# Rotation des labels pour une meilleure lisibilité
plt.xticks(rotation=45)

# Ajouter une ligne de tendance (moyenne mobile)
window = 5
if len(year_counts) >= window:
    moving_avg = year_counts.rolling(window=window, center=True).mean()
    plt.plot(moving_avg.index, moving_avg.values, color='red', linewidth=2, label=f'Moyenne mobile ({window} ans)')
    plt.legend()

plt.tight_layout()
plt.show()

# Calculer l'âge du bâtiment
df['BuildingAge'] = df['DataYear'] - df['YearBuilt']

# Histogramme de l'âge
plt.figure(figsize=(12, 7))
plt.hist(df['BuildingAge'], bins=30, color='mediumseagreen', edgecolor='black', alpha=0.7)
plt.title("Répartition de l'âge des bâtiments (en 2024)", fontsize=16, fontweight='bold')
plt.xlabel("Âge du bâtiment (années)", fontsize=12)
plt.ylabel("Nombre de bâtiments", fontsize=12)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# === ANALYSE DE LA VARIABLE YearBuilt ===
# Nombre total de bâtiments: 1492
# Valeurs manquantes: 0
# Année minimum: 1900
# Année maximum: 2015
# Médiane: 1965.0

# %% [markdown]
# ### Types de sources d'énergie
#
# On crée 2 features pour savoir si le bâtiment :
#
# * utilise une source électrique
# * utilise une source de gaz

# %%
df['UsesElectricity'] = (df['Electricity(kBtu)'] > 0).astype(int)
df['UsesNaturalGas'] = (df['NaturalGas(kBtu)'] > 0).astype(int)

# %% [markdown]
# ### Corrélation entre les features sélectionnées et variables cibles
#
# Nous utilisons la matrice de **Pearson** pour avoir un aperçu des corrélations entre les features elles-mêmes et les variables cibles.
#
# * Nous recherchons à avoir peu de corrélation entre les features entre elles afin d'éviter la redondance des données dans l'entrainement du modèle
# * Nous recherchons à plus faible mesure à voir des corrélations entre les features et les variables cibles afin de maximiser les prédictions du modèle (en régression linéaire seulement)
#
# **Rappel : il convient de ne pas surinterpréter les résultats, car la corrélation de Pearson (et donc la matrice de corrélation associée) ne capte que les relations linéaires et est sensible aux valeurs aberrantes.**

# %%
# Liste des features numériques retenues (à adapter selon tes besoins)

neighborhood_cols = [col for col in df.columns if col.startswith('Neighborhood_')]
type_cols = [col for col in df.columns if col.startswith(primary_type_prefix+'_')]
geo_clusters_cols = [col for col in df.columns if col.startswith(geo_cluster_prefix+'_')]


# Variables cibles
target = [
    'TotalGHGEmissions',
    'SiteEnergyUse(MBtu)'
]

# Variables prédictives
features_selected = [
    'FootprintGFA',
    'PropertyGFABuilding(s)Scaled', # soit buildings soit total, je pense que Building est + représentatif
    #'PropertyGFATotalScaled', # meilleurs résultats en laissant Footprint + total gfa scaled ?
    'BuildingAge',
    'UsesElectricity',
    'UsesNaturalGas',
    'NumberofBuildings', 
    'NumberofFloors',
    'MultipleUsages',    
    'HasSwimmingPool',
    'DataCenterGFA',
    'RefrigeratedWarehouseGFA',
    'ManufacturingIndustrialPlantGFA',
    'SupermarketGroceryStoreGFA',
    'MovieTheaterGFA',
    'MuseumGFA',
    'PropertyGFAParking' # ni plus ni moins ?
]

# Sélectionner uniquement les features retenues
df_selected = df[features_selected + neighborhood_cols + type_cols + geo_clusters_cols]
nb_total_features = len(df_selected.columns)
df_matrix_preview = df[features_selected + target]

# Calculer la matrice de corrélation
corr_matrix = df_matrix_preview.corr(method='pearson')
display_pearson_matrix(corr_matrix, "Matrice de corrélation de Pearson - réduite aux variables numériques")

# Matrice Types (usage des bâtiments)
corr_matrix = df[type_cols + target].corr(method='pearson')
display_pearson_matrix(corr_matrix, "Matrice de corrélation de Pearson - Usages des bâtiments", False)

# Matrice GeoCluster
corr_matrix = df[geo_clusters_cols + target].corr(method='pearson')
display_pearson_matrix(corr_matrix, "Matrice de corrélation de Pearson - Position géographique", False)


print(f"Nombre total de features sélectionnées : {nb_total_features}")
# Out:
# Nombre total de features sélectionnées : 52

# %% [markdown]
# features = ['SiteEnergyUse(MBtu)', 'TotalGHGEmissions', 'PropertyGFATotal', 'BuildingAge']
# sns.pairplot(df[features], kind="reg")
# plt.show()

# %% [markdown]
# ## Résumé des features retenues

# %%
list(df_selected.columns)
# Out:
# ['FootprintGFA',
#  'PropertyGFABuilding(s)Scaled',
#  'BuildingAge',
#  'UsesElectricity',
#  'UsesNaturalGas',
#  'NumberofBuildings',
#  'NumberofFloors',
#  'MultipleUsages',
#  'HasSwimmingPool',
#  'DataCenterGFA',
#  'RefrigeratedWarehouseGFA',
#  'ManufacturingIndustrialPlantGFA',
#  'SupermarketGroceryStoreGFA',
#  'MovieTheaterGFA',
#  'MuseumGFA',
#  'PropertyGFAParking',
#  'Neighborhood_CENTRAL',
#  'Neighborhood_DELRIDGE',
#  'Neighborhood_DOWNTOWN',
#  'Neighborhood_EAST',
#  'Neighborhood_GREATER DUWAMISH',
#  'Neighborhood_LAKE UNION',
#  'Neighborhood_MAGNOLIA / QUEEN ANNE',
#  'Neighborhood_NORTH',
#  'Neighborhood_NORTHEAST',
#  'Neighborhood_NORTHWEST',
#  'Neighborhood_infrequent_sklearn',
#  'Type_Hospital',
#  'Type_Hotel',
#  'Type_K-12 School',
#  'Type_Laboratory',
#  'Type_Large Office',
#  'Type_Medical Office',
#  'Type_Mixed Use Property',
#  'Type_Other',
#  'Type_Refrigerated Warehouse',
#  'Type_Restaurant',
#  'Type_Retail Store',
# ...
