# %%
# On exécute le précédent notebook car on est dépendant des résultats
import sys
import os
from contextlib import redirect_stdout, redirect_stderr

# Désactiver l'affichage AVANT d'importer matplotlib
# %matplotlib agg

with open(os.devnull, 'w') as fnull:
    with redirect_stdout(fnull), redirect_stderr(fnull):
        # %run 2+3_feature-engineering.ipynb

# FORCER la réactivation de l'affichage
# %matplotlib inline

# Réinitialiser matplotlib pour forcer le nouveau backend
import matplotlib
matplotlib.pyplot.close('all')  # Fermer toutes les figures existantes
# Out:
#      OSEBuildingID  DataYear    BuildingType          PrimaryPropertyType  \
# 513            700      2016  NonResidential  Supermarket / Grocery Store
#
#                   PropertyName  ZipCode TaxParcelIdentificationNumber  \
# 513  IUC- Whole Foods Interbay  98119.0                    7666201460
#
#      CouncilDistrictCode           Neighborhood  Latitude  ...  \
# 513                    7  MAGNOLIA / QUEEN ANNE  47.63718  ...
#
#      SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  Electricity(kWh)  \
# 513             12843856.0             0.0               0.0
#
#      Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu)  DefaultData  \
# 513                0.0                 0.0               0.0        False
#
#     ComplianceStatus TotalGHGEmissions  GHGEmissionsIntensity
# 513        Compliant               0.0                    0.0
#
# [1 rows x 41 columns]

# %% [markdown]
# # Modèles pour prédire la consommation en énergie
# ## Régression linéaire

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score, mean_absolute_error

# on fixe un random_state pour la reproductibilité des résultats
random_state = 42

# les variables prédictives
X = df_selected

# Première variable cible : énergie totale utilisée
y = df['SiteEnergyUse(MBtu)']

# on choisit un modèle de régression linéaire
reg = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=random_state)

reg.fit(X_train, y_train)
y_pred_test = reg.predict(X_test)

print(f"MSE: {mean_squared_error(y_test, y_pred_test)}")
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_test))}")
print(f"MAE: {mean_absolute_error(y_test, y_pred_test)}")
print(f"MAPE: {mean_absolute_percentage_error(y_test, y_pred_test)}")
print(f"R²: {r2_score(y_test, y_pred_test)}")

comparaison = pd.DataFrame({'réel': y_test, 'prédit': y_pred_test})
print(comparaison.head(20))

plt.figure(figsize=(10,6))
plt.hist(df['SiteEnergyUse(MBtu)'], bins=100, color='skyblue', edgecolor='black')
plt.xlabel('SiteEnergyUse (MBtu)')
plt.ylabel('Nombre de bâtiments')
plt.title('Distribution de SiteEnergyUse (MBtu)')
plt.grid(True)
plt.show()
# Out:
# MSE: 31828285.25234086
# RMSE: 5641.656250813307
# MAE: 3189.359880774442
# MAPE: 1.517460239982785
# R²: 0.7604231464902063
#               réel        prédit
# 1698    313.528094    140.616965
# 1568    222.255906   2193.770486
# 2901   3605.749750   5846.891215
# 1875   1602.084375   3218.483058
# 1753  14524.386000   4221.933692
# 657    1618.916375    591.815391
# 556   17750.994000  17298.059049
# 366   17225.444000   8207.521647
# 406    3181.045500   4228.558778
# 305    4169.431500   7727.378990
# 1939   1280.263750    656.659650
# 1125  10234.721000   3934.208960
# 2182    229.856406   2277.026996
# 3028   2076.289625   3046.358095
# 80     5448.975000   5668.449699
# 333   11594.121000  24503.319277
# 1292   1832.808750   6288.613021
# 425    1847.401000   2235.929474
# 2414   3168.131000   4647.067440
# 60    16402.563000  10140.694552

# %% [markdown]
# ### Validation croisée
#
# On réeffectue la régression linéaire avec une validation croisée cross_validate.
#
# On crée une fonction qui permet de faire une validation croisée et afficher les résultats pour tous nos autres modèles

# %%
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression

# Fonction pour la validation croisée de modèles et affichage des résultats
def cross_validate_and_print_results(reg, X, y):
    cv_results = cross_validate(
        reg, 
        X, 
        y, 
        cv=5,  # nombre de folds (par défaut 5)
        scoring=['neg_mean_squared_error', 'r2', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error'],
        return_train_score=False
    )

    # Calcul des métriques
    mse_mean = -cv_results['test_neg_mean_squared_error'].mean()
    rmse_mean = np.sqrt(mse_mean)
    mae_mean = -cv_results['test_neg_mean_absolute_error'].mean()
    mape_mean = -cv_results['test_neg_mean_absolute_percentage_error'].mean()
    r2_mean = cv_results['test_r2'].mean()
    
    # Création du tableau
    results_df = pd.DataFrame({
        'Métrique': ['MSE', 'RMSE', 'MAE', 'MAPE (%)', 'R²'],
        'Moyenne': [
            f"{mse_mean:,.0f}",
            f"{rmse_mean:,.1f}",
            f"{mae_mean:,.1f}",
            f"{mape_mean*100:.2f}",
            f"{r2_mean:.4f}"
        ]
    })

    styled_table = (
        results_df.style
        .set_caption("Résultats Validation Croisée")
        .hide(axis="index")
        .set_properties(**{'text-align': 'left'})
        .set_table_styles(
            [
                {"selector": "th", "props": [("text-align", "left")]},
                {"selector": "td", "props": [("min-width", "200px")]}
            ]
        )
    )

    display(styled_table)
# Modèle
reg = LinearRegression()

# Validation croisée
cross_validate_and_print_results(reg, X, y)
# Out:
# <style type="text/css">
# #T_95056 th {
#   text-align: left;
# }
# #T_95056 td {
#   min-width: 200px;
# }
# #T_95056_row0_col0, #T_95056_row0_col1, #T_95056_row1_col0, #T_95056_row1_col1, #T_95056_row2_col0, #T_95056_row2_col1, #T_95056_row3_col0, #T_95056_row3_col1, #T_95056_row4_col0, #T_95056_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_95056">
#   <caption>Résultats Validation Croisée</caption>
#   <thead>
#     <tr>
#       <th id="T_95056_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_95056_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_95056_row0_col0" class="data row0 col0" >MSE</td>
#       <td id="T_95056_row0_col1" class="data row0 col1" >36,237,078</td>
#     </tr>
#     <tr>
#       <td id="T_95056_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_95056_row1_col1" class="data row1 col1" >6,019.7</td>
#     </tr>
#     <tr>
#       <td id="T_95056_row2_col0" class="data row2 col0" >MAE</td>
#       <td id="T_95056_row2_col1" class="data row2 col1" >3,181.8</td>
#     </tr>
#     <tr>
#       <td id="T_95056_row3_col0" class="data row3 col0" >MAPE (%)</td>
#       <td id="T_95056_row3_col1" class="data row3 col1" >136.94</td>
#     </tr>
#     <tr>
#       <td id="T_95056_row4_col0" class="data row4 col0" >R²</td>
#       <td id="T_95056_row4_col1" class="data row4 col1" >0.4958</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Remarque : on constate avec la validation croisée que le modèle semble moins performant que notre premier essai** (ce qui est normal car la validation croisée permet de réduire l'overfit)
#
# * RMSE et MAE moyens **proches** du premier essai
# * MAPE moyen **plus élevé**
# * **R² beaucoup plus bas** : de ~0,75 on passe à ~0.48
#
# ### Bilan
#
# **On constate que la régression linéaire n'est pas adaptée pour prédire la consommation en énergie. On constate également que la distribution de cette variable sur les données statistiques existantes n'est pas linéaire. Ces résultats sont cohérents car la régression linéaire n'est pas adaptée pour prédire une variable dont la distribution est non-linéaire**
#
# ## RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

reg = RandomForestRegressor(n_estimators=100, random_state=random_state)

cross_validate_and_print_results(reg, X, y)
# Out:
# <style type="text/css">
# #T_70b3c th {
#   text-align: left;
# }
# #T_70b3c td {
#   min-width: 200px;
# }
# #T_70b3c_row0_col0, #T_70b3c_row0_col1, #T_70b3c_row1_col0, #T_70b3c_row1_col1, #T_70b3c_row2_col0, #T_70b3c_row2_col1, #T_70b3c_row3_col0, #T_70b3c_row3_col1, #T_70b3c_row4_col0, #T_70b3c_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_70b3c">
#   <caption>Résultats Validation Croisée</caption>
#   <thead>
#     <tr>
#       <th id="T_70b3c_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_70b3c_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_70b3c_row0_col0" class="data row0 col0" >MSE</td>
#       <td id="T_70b3c_row0_col1" class="data row0 col1" >37,926,869</td>
#     </tr>
#     <tr>
#       <td id="T_70b3c_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_70b3c_row1_col1" class="data row1 col1" >6,158.5</td>
#     </tr>
#     <tr>
#       <td id="T_70b3c_row2_col0" class="data row2 col0" >MAE</td>
#       <td id="T_70b3c_row2_col1" class="data row2 col1" >3,068.9</td>
#     </tr>
#     <tr>
#       <td id="T_70b3c_row3_col0" class="data row3 col0" >MAPE (%)</td>
#       <td id="T_70b3c_row3_col1" class="data row3 col1" >95.13</td>
#     </tr>
#     <tr>
#       <td id="T_70b3c_row4_col0" class="data row4 col0" >R²</td>
#       <td id="T_70b3c_row4_col1" class="data row4 col1" >0.5125</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Remarque : on constate un R² un peu meilleur, ainsi qu'une MAE et RMSE un peu meilleures également. Toutefois l'amélioration est faible avec ce modèle, il est difficile de conclure que ce modèle est meilleur**

# %% [markdown]
# ## XGBoost (Extreme Gradient Boosting)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

reg = GradientBoostingRegressor(n_estimators=100, max_depth = 6, random_state=random_state)

cross_validate_and_print_results(reg, X, y)
# Out:
# <style type="text/css">
# #T_ddcdf th {
#   text-align: left;
# }
# #T_ddcdf td {
#   min-width: 200px;
# }
# #T_ddcdf_row0_col0, #T_ddcdf_row0_col1, #T_ddcdf_row1_col0, #T_ddcdf_row1_col1, #T_ddcdf_row2_col0, #T_ddcdf_row2_col1, #T_ddcdf_row3_col0, #T_ddcdf_row3_col1, #T_ddcdf_row4_col0, #T_ddcdf_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_ddcdf">
#   <caption>Résultats Validation Croisée</caption>
#   <thead>
#     <tr>
#       <th id="T_ddcdf_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_ddcdf_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ddcdf_row0_col0" class="data row0 col0" >MSE</td>
#       <td id="T_ddcdf_row0_col1" class="data row0 col1" >39,497,758</td>
#     </tr>
#     <tr>
#       <td id="T_ddcdf_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_ddcdf_row1_col1" class="data row1 col1" >6,284.7</td>
#     </tr>
#     <tr>
#       <td id="T_ddcdf_row2_col0" class="data row2 col0" >MAE</td>
#       <td id="T_ddcdf_row2_col1" class="data row2 col1" >3,068.2</td>
#     </tr>
#     <tr>
#       <td id="T_ddcdf_row3_col0" class="data row3 col0" >MAPE (%)</td>
#       <td id="T_ddcdf_row3_col1" class="data row3 col1" >88.32</td>
#     </tr>
#     <tr>
#       <td id="T_ddcdf_row4_col0" class="data row4 col0" >R²</td>
#       <td id="T_ddcdf_row4_col1" class="data row4 col1" >0.4968</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Remarque : on constate un R² sensiblement meilleur, ainsi qu'une MAE et RMSE un peu meilleures**

# %% [markdown]
# # Modèles pour prédire les émissions de gaz à effet de serre
#
# On va appliquer directement la validation croisée à nos modèles
#
# ## Régression linéaire

# %%
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression

X = df_selected
y = df['TotalGHGEmissions']

plt.figure(figsize=(10,6))
plt.hist(df['TotalGHGEmissions'], bins=100, color='skyblue', edgecolor='black')
plt.xlabel('TotalGHGEmissions')
plt.ylabel('Nombre de bâtiments')
plt.title('Distribution de TotalGHGEmissions')
plt.grid(True)
plt.show()

cross_validate_and_print_results(reg, X, y)
# Out:
# <style type="text/css">
# #T_c5ce1 th {
#   text-align: left;
# }
# #T_c5ce1 td {
#   min-width: 200px;
# }
# #T_c5ce1_row0_col0, #T_c5ce1_row0_col1, #T_c5ce1_row1_col0, #T_c5ce1_row1_col1, #T_c5ce1_row2_col0, #T_c5ce1_row2_col1, #T_c5ce1_row3_col0, #T_c5ce1_row3_col1, #T_c5ce1_row4_col0, #T_c5ce1_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c5ce1">
#   <caption>Résultats Validation Croisée</caption>
#   <thead>
#     <tr>
#       <th id="T_c5ce1_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_c5ce1_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c5ce1_row0_col0" class="data row0 col0" >MSE</td>
#       <td id="T_c5ce1_row0_col1" class="data row0 col1" >28,765</td>
#     </tr>
#     <tr>
#       <td id="T_c5ce1_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_c5ce1_row1_col1" class="data row1 col1" >169.6</td>
#     </tr>
#     <tr>
#       <td id="T_c5ce1_row2_col0" class="data row2 col0" >MAE</td>
#       <td id="T_c5ce1_row2_col1" class="data row2 col1" >83.2</td>
#     </tr>
#     <tr>
#       <td id="T_c5ce1_row3_col0" class="data row3 col0" >MAPE (%)</td>
#       <td id="T_c5ce1_row3_col1" class="data row3 col1" >189.48</td>
#     </tr>
#     <tr>
#       <td id="T_c5ce1_row4_col0" class="data row4 col0" >R²</td>
#       <td id="T_c5ce1_row4_col1" class="data row4 col1" >0.3437</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Bilan
#
# On constate que la **régression linéaire** n'est pas adaptée en l'état pour prédire les émissions de gaz à effet de serre.
# On constate également que la distribution de cette variable sur les données statistiques existantes n'est **pas linéaire**.
# La conclusion est la même que pour la précédente avec la consommation en énergie

# %% [markdown]
# ## RandomForestRegressor

# %%
reg = RandomForestRegressor(n_estimators=100, random_state=random_state)
cross_validate_and_print_results(reg, X, y)
# Out:
# <style type="text/css">
# #T_5f790 th {
#   text-align: left;
# }
# #T_5f790 td {
#   min-width: 200px;
# }
# #T_5f790_row0_col0, #T_5f790_row0_col1, #T_5f790_row1_col0, #T_5f790_row1_col1, #T_5f790_row2_col0, #T_5f790_row2_col1, #T_5f790_row3_col0, #T_5f790_row3_col1, #T_5f790_row4_col0, #T_5f790_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_5f790">
#   <caption>Résultats Validation Croisée</caption>
#   <thead>
#     <tr>
#       <th id="T_5f790_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_5f790_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5f790_row0_col0" class="data row0 col0" >MSE</td>
#       <td id="T_5f790_row0_col1" class="data row0 col1" >28,716</td>
#     </tr>
#     <tr>
#       <td id="T_5f790_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_5f790_row1_col1" class="data row1 col1" >169.5</td>
#     </tr>
#     <tr>
#       <td id="T_5f790_row2_col0" class="data row2 col0" >MAE</td>
#       <td id="T_5f790_row2_col1" class="data row2 col1" >83.4</td>
#     </tr>
#     <tr>
#       <td id="T_5f790_row3_col0" class="data row3 col0" >MAPE (%)</td>
#       <td id="T_5f790_row3_col1" class="data row3 col1" >169.91</td>
#     </tr>
#     <tr>
#       <td id="T_5f790_row4_col0" class="data row4 col0" >R²</td>
#       <td id="T_5f790_row4_col1" class="data row4 col1" >0.3604</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## XGBoost (Extreme Gradient Boosting)

# %%
reg = GradientBoostingRegressor(n_estimators=100, random_state=random_state)
cross_validate_and_print_results(reg, X, y)
# Out:
# <style type="text/css">
# #T_ec756 th {
#   text-align: left;
# }
# #T_ec756 td {
#   min-width: 200px;
# }
# #T_ec756_row0_col0, #T_ec756_row0_col1, #T_ec756_row1_col0, #T_ec756_row1_col1, #T_ec756_row2_col0, #T_ec756_row2_col1, #T_ec756_row3_col0, #T_ec756_row3_col1, #T_ec756_row4_col0, #T_ec756_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_ec756">
#   <caption>Résultats Validation Croisée</caption>
#   <thead>
#     <tr>
#       <th id="T_ec756_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_ec756_level0_col1" class="col_heading level0 col1" >Moyenne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ec756_row0_col0" class="data row0 col0" >MSE</td>
#       <td id="T_ec756_row0_col1" class="data row0 col1" >28,774</td>
#     </tr>
#     <tr>
#       <td id="T_ec756_row1_col0" class="data row1 col0" >RMSE</td>
#       <td id="T_ec756_row1_col1" class="data row1 col1" >169.6</td>
#     </tr>
#     <tr>
#       <td id="T_ec756_row2_col0" class="data row2 col0" >MAE</td>
#       <td id="T_ec756_row2_col1" class="data row2 col1" >84.0</td>
#     </tr>
#     <tr>
#       <td id="T_ec756_row3_col0" class="data row3 col0" >MAPE (%)</td>
#       <td id="T_ec756_row3_col1" class="data row3 col1" >208.95</td>
#     </tr>
#     <tr>
#       <td id="T_ec756_row4_col0" class="data row4 col0" >R²</td>
#       <td id="T_ec756_row4_col1" class="data row4 col1" >0.3633</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Optimisation du XGBoost
#
# On a constaté que le meilleur modèle dans notre cas est le XGBoost.
# On va maintenant chercher à optimiser son utilisation afin d'améliorer les prédictions

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_absolute_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
# les variables prédictives
X = df_selected

# Variables prédictives et cible
X = df_selected
y = df['SiteEnergyUse(MBtu)']

# Hyperparamètres à tester
parameters = {
    'max_depth': np.arange(2, 30, 2),
    'n_estimators': [50, 100, 150, 200, 250, 300]
}
model = GradientBoostingRegressor(random_state=42)

# GridSearchCV
gridsearch = GridSearchCV(model, parameters, cv=5,
                          scoring='r2',
                          #scoring='neg_mean_absolute_error',
                          verbose=2)
gridsearch.fit(X, y)

print("Meilleurs hyperparamètres:", gridsearch.best_params_)
print("Best CV score :", gridsearch.best_score_)

# Importances des features
feature_names = X.columns.tolist()
best_model = gridsearch.best_estimator_
importances = best_model.feature_importances_
feature_importance_df = (pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False))

print("\nImportances des features (Top 10):")
print(feature_importance_df.head(10).to_string(index=False))
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# [CV] END .......................max_depth=2, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=2, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=2, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=2, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=2, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END ......................max_depth=2, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=150; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END ......................max_depth=2, n_estimators=250; total time=   0.3s
# [CV] END ......................max_depth=2, n_estimators=250; total time=   0.3s
# [CV] END ......................max_depth=2, n_estimators=250; total time=   0.3s
# [CV] END ......................max_depth=2, n_estimators=250; total time=   0.3s
# [CV] END ......................max_depth=2, n_estimators=250; total time=   0.3s
# [CV] END ......................max_depth=2, n_estimators=300; total time=   0.3s
# [CV] END ......................max_depth=2, n_estimators=300; total time=   0.3s
# [CV] END ......................max_depth=2, n_estimators=300; total time=   0.4s
# [CV] END ......................max_depth=2, n_estimators=300; total time=   0.4s
# [CV] END ......................max_depth=2, n_estimators=300; total time=   0.4s
# [CV] END .......................max_depth=4, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=4, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=4, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=4, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=4, n_estimators=50; total time=   0.1s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=4, n_estimators=100; total time=   0.2s
# [CV] END ......................max_depth=4, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=4, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=4, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=4, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=4, n_estimators=150; total time=   0.3s
# [CV] END ......................max_depth=4, n_estimators=200; total time=   0.4s
# [CV] END ......................max_depth=4, n_estimators=200; total time=   0.4s
# [CV] END ......................max_depth=4, n_estimators=200; total time=   0.4s
# [CV] END ......................max_depth=4, n_estimators=200; total time=   0.4s
# [CV] END ......................max_depth=4, n_estimators=200; total time=   0.4s
# [CV] END ......................max_depth=4, n_estimators=250; total time=   0.5s
# [CV] END ......................max_depth=4, n_estimators=250; total time=   0.5s
# [CV] END ......................max_depth=4, n_estimators=250; total time=   0.5s
# [CV] END ......................max_depth=4, n_estimators=250; total time=   0.5s
# [CV] END ......................max_depth=4, n_estimators=250; total time=   0.5s
# [CV] END ......................max_depth=4, n_estimators=300; total time=   0.7s
# [CV] END ......................max_depth=4, n_estimators=300; total time=   0.7s
# [CV] END ......................max_depth=4, n_estimators=300; total time=   0.6s
# [CV] END ......................max_depth=4, n_estimators=300; total time=   0.6s
# [CV] END ......................max_depth=4, n_estimators=300; total time=   0.6s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.2s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.1s
# [CV] END .......................max_depth=6, n_estimators=50; total time=   0.2s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=100; total time=   0.3s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=150; total time=   0.4s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.6s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.6s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.6s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.6s
# [CV] END ......................max_depth=6, n_estimators=200; total time=   0.6s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.7s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.7s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.7s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.7s
# [CV] END ......................max_depth=6, n_estimators=250; total time=   0.7s
# [CV] END ......................max_depth=6, n_estimators=300; total time=   0.8s
# [CV] END ......................max_depth=6, n_estimators=300; total time=   0.9s
# [CV] END ......................max_depth=6, n_estimators=300; total time=   0.9s
# [CV] END ......................max_depth=6, n_estimators=300; total time=   0.9s
# [CV] END ......................max_depth=6, n_estimators=300; total time=   0.9s
# [CV] END .......................max_depth=8, n_estimators=50; total time=   0.2s
# [CV] END .......................max_depth=8, n_estimators=50; total time=   0.2s
# [CV] END .......................max_depth=8, n_estimators=50; total time=   0.2s
# [CV] END .......................max_depth=8, n_estimators=50; total time=   0.2s
# [CV] END .......................max_depth=8, n_estimators=50; total time=   0.2s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   0.4s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   0.4s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   0.4s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   0.4s
# [CV] END ......................max_depth=8, n_estimators=100; total time=   0.4s
# [CV] END ......................max_depth=8, n_estimators=150; total time=   0.5s
# [CV] END ......................max_depth=8, n_estimators=150; total time=   0.6s
# [CV] END ......................max_depth=8, n_estimators=150; total time=   0.6s
# [CV] END ......................max_depth=8, n_estimators=150; total time=   0.6s
# [CV] END ......................max_depth=8, n_estimators=150; total time=   0.6s
# [CV] END ......................max_depth=8, n_estimators=200; total time=   0.7s
# [CV] END ......................max_depth=8, n_estimators=200; total time=   0.7s
# [CV] END ......................max_depth=8, n_estimators=200; total time=   0.8s
# [CV] END ......................max_depth=8, n_estimators=200; total time=   0.8s
# [CV] END ......................max_depth=8, n_estimators=200; total time=   0.8s
# [CV] END ......................max_depth=8, n_estimators=250; total time=   0.9s
# [CV] END ......................max_depth=8, n_estimators=250; total time=   0.9s
# [CV] END ......................max_depth=8, n_estimators=250; total time=   0.9s
# [CV] END ......................max_depth=8, n_estimators=250; total time=   0.9s
# [CV] END ......................max_depth=8, n_estimators=250; total time=   0.9s
# [CV] END ......................max_depth=8, n_estimators=300; total time=   1.1s
# [CV] END ......................max_depth=8, n_estimators=300; total time=   1.1s
# [CV] END ......................max_depth=8, n_estimators=300; total time=   1.1s
# [CV] END ......................max_depth=8, n_estimators=300; total time=   1.1s
# [CV] END ......................max_depth=8, n_estimators=300; total time=   1.1s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.2s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.2s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.2s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.2s
# [CV] END ......................max_depth=10, n_estimators=50; total time=   0.2s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.4s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=150; total time=   0.7s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=200; total time=   0.9s
# [CV] END .....................max_depth=10, n_estimators=250; total time=   1.1s
# [CV] END .....................max_depth=10, n_estimators=250; total time=   1.1s
# [CV] END .....................max_depth=10, n_estimators=250; total time=   1.2s
# [CV] END .....................max_depth=10, n_estimators=250; total time=   1.2s
# [CV] END .....................max_depth=10, n_estimators=250; total time=   1.2s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   1.4s
# [CV] END .....................max_depth=10, n_estimators=300; total time=   1.4s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=12, n_estimators=50; total time=   0.3s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=12, n_estimators=100; total time=   0.5s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=150; total time=   0.8s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   1.1s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   1.1s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   1.1s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   1.1s
# [CV] END .....................max_depth=12, n_estimators=200; total time=   1.1s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   1.3s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   1.3s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   1.3s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   1.4s
# [CV] END .....................max_depth=12, n_estimators=250; total time=   1.3s
# [CV] END .....................max_depth=12, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=12, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=12, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=12, n_estimators=300; total time=   1.6s
# [CV] END .....................max_depth=12, n_estimators=300; total time=   1.6s
# [CV] END ......................max_depth=14, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=14, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=14, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=14, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=14, n_estimators=50; total time=   0.3s
# [CV] END .....................max_depth=14, n_estimators=100; total time=   0.6s
# [CV] END .....................max_depth=14, n_estimators=100; total time=   0.6s
# [CV] END .....................max_depth=14, n_estimators=100; total time=   0.6s
# [CV] END .....................max_depth=14, n_estimators=100; total time=   0.6s
# [CV] END .....................max_depth=14, n_estimators=100; total time=   0.6s
# [CV] END .....................max_depth=14, n_estimators=150; total time=   0.9s
# [CV] END .....................max_depth=14, n_estimators=150; total time=   0.9s
# [CV] END .....................max_depth=14, n_estimators=150; total time=   0.9s
# [CV] END .....................max_depth=14, n_estimators=150; total time=   0.9s
# [CV] END .....................max_depth=14, n_estimators=150; total time=   0.9s
# [CV] END .....................max_depth=14, n_estimators=200; total time=   1.3s
# [CV] END .....................max_depth=14, n_estimators=200; total time=   1.2s
# [CV] END .....................max_depth=14, n_estimators=200; total time=   1.2s
# [CV] END .....................max_depth=14, n_estimators=200; total time=   1.3s
# [CV] END .....................max_depth=14, n_estimators=200; total time=   1.2s
# [CV] END .....................max_depth=14, n_estimators=250; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=250; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=250; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=250; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=250; total time=   1.5s
# [CV] END .....................max_depth=14, n_estimators=300; total time=   1.8s
# [CV] END .....................max_depth=14, n_estimators=300; total time=   1.8s
# [CV] END .....................max_depth=14, n_estimators=300; total time=   1.9s
# [CV] END .....................max_depth=14, n_estimators=300; total time=   1.9s
# [CV] END .....................max_depth=14, n_estimators=300; total time=   1.8s
# [CV] END ......................max_depth=16, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=16, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=16, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=16, n_estimators=50; total time=   0.3s
# [CV] END ......................max_depth=16, n_estimators=50; total time=   0.3s
# [CV] END .....................max_depth=16, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=16, n_estimators=150; total time=   1.0s
# [CV] END .....................max_depth=16, n_estimators=150; total time=   1.0s
# [CV] END .....................max_depth=16, n_estimators=150; total time=   1.0s
# [CV] END .....................max_depth=16, n_estimators=150; total time=   1.0s
# [CV] END .....................max_depth=16, n_estimators=150; total time=   1.0s
# [CV] END .....................max_depth=16, n_estimators=200; total time=   1.3s
# [CV] END .....................max_depth=16, n_estimators=200; total time=   1.4s
# [CV] END .....................max_depth=16, n_estimators=200; total time=   1.4s
# [CV] END .....................max_depth=16, n_estimators=200; total time=   1.4s
# [CV] END .....................max_depth=16, n_estimators=200; total time=   1.4s
# [CV] END .....................max_depth=16, n_estimators=250; total time=   1.7s
# [CV] END .....................max_depth=16, n_estimators=250; total time=   1.7s
# [CV] END .....................max_depth=16, n_estimators=250; total time=   1.7s
# [CV] END .....................max_depth=16, n_estimators=250; total time=   1.7s
# [CV] END .....................max_depth=16, n_estimators=250; total time=   1.7s
# [CV] END .....................max_depth=16, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=16, n_estimators=300; total time=   2.0s
# [CV] END .....................max_depth=16, n_estimators=300; total time=   2.1s
# [CV] END .....................max_depth=16, n_estimators=300; total time=   2.1s
# [CV] END .....................max_depth=16, n_estimators=300; total time=   2.1s
# [CV] END ......................max_depth=18, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=18, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=18, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=18, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=18, n_estimators=50; total time=   0.4s
# [CV] END .....................max_depth=18, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=18, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=18, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=18, n_estimators=100; total time=   0.7s
# [CV] END .....................max_depth=18, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=18, n_estimators=150; total time=   1.1s
# [CV] END .....................max_depth=18, n_estimators=150; total time=   1.1s
# [CV] END .....................max_depth=18, n_estimators=150; total time=   1.1s
# [CV] END .....................max_depth=18, n_estimators=150; total time=   1.1s
# [CV] END .....................max_depth=18, n_estimators=150; total time=   1.1s
# [CV] END .....................max_depth=18, n_estimators=200; total time=   1.5s
# [CV] END .....................max_depth=18, n_estimators=200; total time=   1.5s
# [CV] END .....................max_depth=18, n_estimators=200; total time=   1.5s
# [CV] END .....................max_depth=18, n_estimators=200; total time=   1.5s
# [CV] END .....................max_depth=18, n_estimators=200; total time=   1.5s
# [CV] END .....................max_depth=18, n_estimators=250; total time=   1.8s
# [CV] END .....................max_depth=18, n_estimators=250; total time=   1.9s
# [CV] END .....................max_depth=18, n_estimators=250; total time=   1.9s
# [CV] END .....................max_depth=18, n_estimators=250; total time=   1.9s
# [CV] END .....................max_depth=18, n_estimators=250; total time=   1.9s
# [CV] END .....................max_depth=18, n_estimators=300; total time=   2.2s
# [CV] END .....................max_depth=18, n_estimators=300; total time=   2.3s
# [CV] END .....................max_depth=18, n_estimators=300; total time=   2.3s
# [CV] END .....................max_depth=18, n_estimators=300; total time=   2.3s
# [CV] END .....................max_depth=18, n_estimators=300; total time=   2.2s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=20, n_estimators=50; total time=   0.4s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=20, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=20, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=20, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=20, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=20, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=20, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=20, n_estimators=250; total time=   2.0s
# [CV] END .....................max_depth=20, n_estimators=250; total time=   2.0s
# [CV] END .....................max_depth=20, n_estimators=250; total time=   2.0s
# [CV] END .....................max_depth=20, n_estimators=250; total time=   2.0s
# [CV] END .....................max_depth=20, n_estimators=250; total time=   2.0s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   2.4s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   2.4s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   2.4s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   2.3s
# [CV] END .....................max_depth=20, n_estimators=300; total time=   2.4s
# [CV] END ......................max_depth=22, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=22, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=22, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=22, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=22, n_estimators=50; total time=   0.4s
# [CV] END .....................max_depth=22, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=22, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=22, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=22, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=22, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=22, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=22, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=22, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=22, n_estimators=200; total time=   1.7s
# [CV] END .....................max_depth=22, n_estimators=200; total time=   1.7s
# [CV] END .....................max_depth=22, n_estimators=200; total time=   1.6s
# [CV] END .....................max_depth=22, n_estimators=250; total time=   2.1s
# [CV] END .....................max_depth=22, n_estimators=250; total time=   2.1s
# [CV] END .....................max_depth=22, n_estimators=250; total time=   2.1s
# [CV] END .....................max_depth=22, n_estimators=250; total time=   2.1s
# [CV] END .....................max_depth=22, n_estimators=250; total time=   2.0s
# [CV] END .....................max_depth=22, n_estimators=300; total time=   2.5s
# [CV] END .....................max_depth=22, n_estimators=300; total time=   2.5s
# [CV] END .....................max_depth=22, n_estimators=300; total time=   2.5s
# [CV] END .....................max_depth=22, n_estimators=300; total time=   2.5s
# [CV] END .....................max_depth=22, n_estimators=300; total time=   2.4s
# [CV] END ......................max_depth=24, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=24, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=24, n_estimators=50; total time=   0.5s
# [CV] END ......................max_depth=24, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=24, n_estimators=50; total time=   0.4s
# [CV] END .....................max_depth=24, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=24, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=24, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=24, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=24, n_estimators=100; total time=   0.8s
# [CV] END .....................max_depth=24, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=24, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=24, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=24, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=24, n_estimators=150; total time=   1.2s
# [CV] END .....................max_depth=24, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=24, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=24, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=24, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=24, n_estimators=200; total time=   1.7s
# [CV] END .....................max_depth=24, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=24, n_estimators=250; total time=   2.1s
# [CV] END .....................max_depth=24, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=24, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=24, n_estimators=250; total time=   2.0s
# [CV] END .....................max_depth=24, n_estimators=300; total time=   2.6s
# [CV] END .....................max_depth=24, n_estimators=300; total time=   2.6s
# [CV] END .....................max_depth=24, n_estimators=300; total time=   2.6s
# [CV] END .....................max_depth=24, n_estimators=300; total time=   2.6s
# [CV] END .....................max_depth=24, n_estimators=300; total time=   2.2s
# [CV] END ......................max_depth=26, n_estimators=50; total time=   0.5s
# [CV] END ......................max_depth=26, n_estimators=50; total time=   0.5s
# [CV] END ......................max_depth=26, n_estimators=50; total time=   0.5s
# [CV] END ......................max_depth=26, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=26, n_estimators=50; total time=   0.4s
# [CV] END .....................max_depth=26, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=26, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=26, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=26, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=26, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=26, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=26, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=26, n_estimators=150; total time=   1.4s
# [CV] END .....................max_depth=26, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=26, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=26, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=26, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=26, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=26, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=26, n_estimators=200; total time=   1.7s
# [CV] END .....................max_depth=26, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=26, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=26, n_estimators=250; total time=   2.3s
# [CV] END .....................max_depth=26, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=26, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=26, n_estimators=300; total time=   2.4s
# [CV] END .....................max_depth=26, n_estimators=300; total time=   2.7s
# [CV] END .....................max_depth=26, n_estimators=300; total time=   2.6s
# [CV] END .....................max_depth=26, n_estimators=300; total time=   2.3s
# [CV] END .....................max_depth=26, n_estimators=300; total time=   2.4s
# [CV] END ......................max_depth=28, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=28, n_estimators=50; total time=   0.5s
# [CV] END ......................max_depth=28, n_estimators=50; total time=   0.5s
# [CV] END ......................max_depth=28, n_estimators=50; total time=   0.4s
# [CV] END ......................max_depth=28, n_estimators=50; total time=   0.4s
# [CV] END .....................max_depth=28, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=28, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=28, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=28, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=28, n_estimators=100; total time=   0.9s
# [CV] END .....................max_depth=28, n_estimators=150; total time=   1.4s
# [CV] END .....................max_depth=28, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=28, n_estimators=150; total time=   1.4s
# [CV] END .....................max_depth=28, n_estimators=150; total time=   1.4s
# [CV] END .....................max_depth=28, n_estimators=150; total time=   1.3s
# [CV] END .....................max_depth=28, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=28, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=28, n_estimators=200; total time=   1.9s
# [CV] END .....................max_depth=28, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=28, n_estimators=200; total time=   1.8s
# [CV] END .....................max_depth=28, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=28, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=28, n_estimators=250; total time=   2.3s
# [CV] END .....................max_depth=28, n_estimators=250; total time=   2.2s
# [CV] END .....................max_depth=28, n_estimators=250; total time=   2.1s
# [CV] END .....................max_depth=28, n_estimators=300; total time=   2.4s
# [CV] END .....................max_depth=28, n_estimators=300; total time=   2.6s
# [CV] END .....................max_depth=28, n_estimators=300; total time=   2.3s
# [CV] END .....................max_depth=28, n_estimators=300; total time=   2.3s
# [CV] END .....................max_depth=28, n_estimators=300; total time=   2.3s
# Meilleurs hyperparamètres: {'max_depth': np.int64(2), 'n_estimators': 100}
# Best CV score : 0.5531330172323398
#
# Importances des features (Top 10):
#                      Feature  Importance
# PropertyGFABuilding(s)Scaled    0.788010
#               NumberofFloors    0.033520
#                DataCenterGFA    0.032175
#                Type_Hospital    0.026574
#           PropertyGFAParking    0.024147
#              Type_Laboratory    0.019345
#                 FootprintGFA    0.013230
#   SupermarketGroceryStoreGFA    0.011655
#               Type_Warehouse    0.010260
#                   Type_Other    0.009328
